# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.rand(10))
plt.show()

# %%
# 魔法函数，嵌入图表
# %matplotlib inline
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y)
#直接嵌入图表，不用plt.show()

# %%
#魔法函数，弹出可交互的matplotlib窗口
# %matplotlib notebook
s = pd.Series(np.random.randn(100))
s.plot(style='k--o', figsize=(10, 5))
#可交互的matplotlib窗口，不用plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#此处有点问题，后面解决

# %matplotlib qt5
df = pd.DataFrame(np.random.rand(50, 2), columns=['A', 'B'])
df.hist(figsize=(12, 5), color='g', alpha=0.8)
#可交互控制台
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-c48eace28d37> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt5')
#       2 df = pd.DataFrame(np.random.rand(50, 2), columns=['A', 'B'])
#       3 df.hist(figsize=(12, 5), color='g', alpha=0.8)
#       4 #可交互控制台
#
# d:\program files (x86)\py37\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-108> in matplotlib(self, line)
#
# d:\program files (x86)\py37\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
# ...

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['A', 'B'])
print(df)
fig = df.plot(figsize=(6,4))
print(fig, type(fig))
# Out:
#           A         B
# 0  0.297913  0.552583
# 1  0.410655  0.789660
# 2  0.961065  0.761061
# 3  0.304318  0.597537
# 4  0.198217  0.067221
# 5  0.604446  0.232734
# 6  0.709368  0.258599
# 7  0.599568  0.293562
# 8  0.058206  0.035366
# 9  0.002148  0.518171
# AxesSubplot(0.125,0.125;0.775x0.755) <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)
plt.plot(x, c)
plt.plot(x, s)

plt.grid(True, linestyle='--', color='gray', linewidth='0.5', axis='x')
#显示网络
#linestyle:线型
#color:颜色
#linewidth:宽度
#axis:x,y,both,显示x/y/两者的格网


#刻度显示
# plt.tick_params(bottom='on', top='off', left='on', right='off')

#刻度的方向
import matplotlib
matplotlib.rcParams['xtick.direction'] = 'in'
matplotlib.rcParams['ytick.direction'] = 'out'

frame = plt.gca()
#关闭坐标轴
# plt.axis('off')
frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)
#x/y轴不可见

# %%
# linestyle参数
import matplotlib.pyplot as plt
plt.plot([i**2 for i in range(100)], linestyle=':')
# '-' solid line style
# '--' dashed line style
# '-. ' dash-dot line style
# ':' dotted line style

# %%
# marker参数
import pandas as pd
import numpy as np

s = pd.Series(np.random.randn(10).cumsum())
s.plot(linestyle='--', marker='o')

# %%
# color参数
plt.hist(np.random.randn(100), color='y', alpha=0.8)
# alpha:0-1,透明度
# 常用颜色简写：red-r, green-g, red-r, blue-b
# Out:
# (array([ 3.,  5., 10., 19., 17., 18., 15.,  8.,  4.,  1.]),
#  array([-2.25314002, -1.78300654, -1.31287305, -0.84273957, -0.37260608,
#          0.0975274 ,  0.56766089,  1.03779437,  1.50792786,  1.97806134,
#          2.44819483]),
#  <a list of 10 Patch objects>)

# %%
# style参数，可以包含linestyle,marker, color
ts = pd.Series(np.random.randn(1000).cumsum(), index=pd.date_range('1/1/2000', periods=1000))
ts.plot(style='--go', grid=True)

# %%
# 整体风格样式
import matplotlib.style as psl
# print(plt.style.available)
print(psl.available)
# 查看样式列表
psl.use('dark_background')
ts = pd.Series(np.random.randn(1000).cumsum(), index=pd.date_range('1/1/2000', periods=1000))
ts.plot(style='--g', grid=True, figsize=(10, 6))
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
# 刻度
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

t = np.arange(0.0, 100.0, 1)
s = np.sin(0.1*np.pi*t)*np.exp(-t*0.01)
ax = plt.subplot(111)
plt.plot(t, s, '--*')
plt.grid(True, linestyle='--', color='gray', linewidth='0.5', axis='both')
# 网格
# plt.legend() # 图例


xmajorLocator = MultipleLocator(10) # 将x轴主刻度标签设置为10的倍数
xmajorFormatter = FormatStrFormatter('%.0f')# 设置x轴标签文本的格式
xminorLocator = MultipleLocator(5) # 将x轴次刻度标签设置为5的倍数
ymajorLocator = MultipleLocator(0.5)
ymajorFormatter = FormatStrFormatter('%.1f')
yminorLocator = MultipleLocator(0.1)

ax.xaxis.set_major_locator(xmajorLocator)
ax.xaxis.set_major_formatter(xmajorFormatter)
ax.xaxis.set_minor_locator(xminorLocator)


ax.yaxis.set_major_locator(ymajorLocator)
ax.yaxis.set_major_formatter(ymajorFormatter)
ax.yaxis.set_minor_locator(yminorLocator)

ax.xaxis.grid(True, which='both') # x轴的坐标轴网格显示
ax.yaxis.grid(True, which='both')

ax.xaxis.set_major_locator(plt.NullLocator())# 注意是NullLocator()实例
ax.yaxis.set_minor_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.yaxis.set_major_formatter(plt.NullFormatter())
# Out:
# No handles with labels found to put in legend.

# %%
# 注释
df = pd.DataFrame(np.random.rand(10, 2))
print(df)
df.plot(style='--o')
plt.text(5, 0.5, 'shuxiangguo', fontsize=10)
# Out:
#           0         1
# 0  0.535168  0.237551
# 1  0.853981  0.001490
# 2  0.187311  0.689693
# 3  0.485641  0.861977
# 4  0.455201  0.040699
# 5  0.282265  0.219520
# 6  0.947124  0.285206
# 7  0.170811  0.279576
# 8  0.774330  0.499930
# 9  0.899820  0.338145
# Text(5, 0.5, 'shuxiangguo')

# %%
# 图标的存储，输出
df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))
# print(df)
df = df.cumsum()
# print(df)

df.plot(style='--.', alpha=0.5)
plt.legend(loc='upper left')

plt.savefig('F:/pic1.pdf', dpi=800, bbox_inches='tight', facecolor='g', edgecolor='b')
# 图片的格式可支持：png,pdf,svg,ps,epg...
# dpi是分辨率
# bbox_inches：图表需要保存的部分，如果设置为‘tight’，则尝试减除图标周围的空白部分
# facecolor,edgecolor:图像的背景色，默认为‘w’白色

# %%
# 子图
"""
在matplotlib中，整个图像为一个Figure对象
在Figure对象中可以包含一个或多个Axes对象
每个Axes（ax）对象都是一个拥有自己坐标系统的绘图区域

plt.figure,plt.subplot
"""

# plt.figure() #绘图对象
fig1 = plt.figure(num=1, figsize=(4,2))
plt.plot(np.random.rand(50).cumsum(), 'k--')
fig2 = plt.figure(num=2, figsize=(4,2))
plt.plot(50-np.random.rand(50).cumsum(), 'k--')

# 当我们调用plt.plot()时，如果没有设置plt.figure(),则会自动调用figure()生成一个figure，严格地说，是生成subplots(111)

# %%
# 子图创建1-先建立图然后填充图表
fig = plt.figure(figsize=(10, 6), facecolor='gray')
ax1 = fig.add_subplot(2,2,1) # 第一行的左图
plt.plot(np.random.rand(50).cumsum(), 'k--')
plt.plot(np.random.randn(50).cumsum(), 'b--')
# 先创建图标，然后生成子图，（2,2,1）表示生成2*2的矩阵表格，1表示选择第一个位置，顺序是从左到右，从上到下。
# 创建子图后绘制图标，会绘制到最后一个子图

ax2 = fig.add_subplot(2,2,2) # 第一行的右图
ax2.hist(np.random.rand(50), alpha=0.5)

ax4 = fig.add_subplot(2,2,4) # 第二行的右图
df2 = pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])
ax4.plot(df2, alpha=0.5, linestyle='--', marker='.')

# %%
# 子图创建2-创建 subplot对象的numpy数组---->plt.subplots
fig, axes = plt.subplots(2,3,figsize=(10, 4))
ts = pd.Series(np.random.randn(1000).cumsum())
print(axes, axes.shape, type(axes))
ax1 = axes[0][1]
ax1.plot(ts)
axes[0][0].plot(np.random.rand(100))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x1336D710>
# ...
#   <matplotlib.axes._subplots.AxesSubplot object at 0x13535390>]] (2, 3) <class 'numpy.ndarray'>

# %%
# plt.subplots()参数调整

# sharex,sharey是否共享x,y轴刻度
fig, axes = plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i][j].hist(np.random.randn(500), color='k', alpha=0.5)
# wspace,hspace 用于控制宽度和高度的百分比，比如subplot之间的间距
plt.subplots_adjust(wspace=0.5, hspace=0.5)

# %%
# 创建子图---多系列图，分别绘制
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
df.plot(style='--.', alpha=0.5, grid=True, figsize=(8,8),
        subplots=True, 
        sharex=False,
       layout=(2,3))

# subplots参数：是否分别绘制子图
# layout: 绘制子图矩阵，按顺序填充
plt.subplots_adjust(wspace=0, hspace=0)

# %%
# 基本图标绘制
# 图标类型：线性图、柱状图、密度图，以横纵坐标俩个维度为主
# 同时可延展出多种其他图标样式

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Series直接生成图表
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
print(ts.head)
ts.plot(kind='line',
       label='hehe',
       style='--g.',
        color='r',
        alpha=0.8,
        ylim=[-5, 5],
        title="table",
        legend=True,
        rot=45,
        use_index=True
       )
# Out:
# <bound method NDFrame.head of 2000-01-01    -0.146155
# 2000-01-02    -1.456425
# 2000-01-03    -2.162384
# 2000-01-04    -2.774294
# 2000-01-05    -2.959101
# 2000-01-06    -4.102799
# 2000-01-07    -2.846518
# 2000-01-08    -3.464179
# 2000-01-09    -2.998126
# 2000-01-10    -3.524313
# 2000-01-11    -4.172267
# 2000-01-12    -4.498049
# 2000-01-13    -4.687883
# 2000-01-14    -5.001489
# 2000-01-15    -5.336892
# 2000-01-16    -5.571702
# 2000-01-17    -4.904770
# 2000-01-18    -3.871012
# 2000-01-19    -4.507806
# 2000-01-20    -4.121394
# 2000-01-21    -4.632277
# 2000-01-22    -3.406514
# 2000-01-23    -3.496968
# 2000-01-24    -3.511864
# 2000-01-25    -2.809548
# 2000-01-26    -1.264536
# 2000-01-27    -1.824708
# 2000-01-28    -0.727493
# 2000-01-29    -0.413015
# 2000-01-30    -0.515838
#                 ...
# 2002-08-28   -55.026076
# 2002-08-29   -55.789641
# 2002-08-30   -57.754857
# 2002-08-31   -57.018664
# 2002-09-01   -57.869445
# 2002-09-02   -56.862322
# ...

# %%
# DataFrame直接生成图表
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()
print(df.head())
df.plot(kind='line',
        style='--.',
        alpha=0.4,
        use_index=False,
        subplots=True,
        colormap='Greens',
        legend=True,
        figsize=(8,6)
       )
# Out:
#                    A         B         C         D
# 2000-01-01 -0.450735 -1.759010  0.182497 -1.084094
# 2000-01-02 -0.187076 -2.803079  1.126191 -1.016016
# 2000-01-03 -0.845117 -3.388028  0.570867 -1.044596
# 2000-01-04 -2.173551 -2.716089  1.083445 -1.544056
# 2000-01-05 -3.236356 -3.053501  0.123993 -3.198006
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1B615670>,
# ...
#       dtype=object)

# %%
# 柱状图、堆叠图
fig, axes = plt.subplots(4, 1, figsize=(10, 10))
s = pd.Series(np.random.randint(0, 10, 16), index=list('abcdefghijklmnop'))
# print(s)
df = pd.DataFrame(np.random.rand(10, 3), columns=['a', 'b', 'c'])
# print(df)

# 单系列
s.plot(kind='bar', ax=axes[0])

# 多系列
df.plot(kind='bar', ax=axes[1])

# 多系列，堆叠图
df.plot(kind='bar', stacked=True, ax=axes[2])

df.plot.barh(ax=axes[3])

# %%
# 柱状图 plt.bar()

plt.figure(figsize=(10, 4))
x = np.arange(10)
y1 = np.random.rand(10)
y2 = -np.random.rand(10)


# facecolor：柱状图里面的颜色
# edgecolor: 柱状图边框的颜色
# xerr/yerr:x/y方向的error bar
plt.bar(x, y1, width=1, facecolor='yellowgreen', edgecolor='white', yerr=y1*0.1)
plt.bar(x, y2, width=1, facecolor='lightskyblue', edgecolor='red', yerr=y2*0.1)

#给图添加text
for i, j in zip(x, y1):
    plt.text(i+0.01, j-0.15, '%.2f' % j, color='white')
    
for i, j in zip(x, y2):
    plt.text(i+0.01, j+0.05, '%.2f' % -j, color='white')

# %%
# 面积图

fig, axes = plt.subplots(2, 1, figsize=(8, 6))
df1 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2 = pd.DataFrame(np.random.randn(10, 4), columns=['a', 'b', 'c', 'd'])

df1.plot.area(colormap='Greens_r', alpha=0.5, ax=axes[0])
df2.plot.area(colormap='Set2',stacked=False, alpha=0.4, ax=axes[1])

# 使用Series.plot.area()和DataFrame.plot.area()创建面积图
# stacked:是否堆叠，默认情况下，区域图被堆叠
# 为了产生堆叠面积图，每列必须是正值或负值
# 当有数据是NaN时候，自动填充0，所以图标签需要清洗掉缺失值。

# %%
# 填图
fig, axes = plt.subplots(2, 1, figsize=(8, 6))
x = np.linspace(0, 1, 500)
y1 = np.sin(4*np.pi*x)*np.exp(-5*x)
y2 = -np.sin(4*np.pi*x)*np.exp(-5*x)
axes[0].fill(x, y1, 'r', alpha=0.5, label='y1')
axes[0].fill(x, y2, 'g', alpha=0.5, label='y2')

# 对函数与坐标轴之间的区域进行填充，使用fill函数
# 也可以 plt.fill(x, y1, 'r', x, y2, 'g', alpha=0.5)

x = np.linspace(0, 5*np.pi, 1000)
y1 =np.sin(x)
y2 = np.sin(2*x)
axes[1].fill_between(x, y1, y2, color='r', alpha=0.5, label='area')

for i in range(2):
    axes[i].legend()
    axes[i].grid()

# %%
# 饼图
s = pd.Series(3*np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
plt.axis('equal')
plt.pie(s, 
       explode=[0, 0, 0, 0],
       labels=s.index,
        colors=['r', 'g', 'b', 'c'],
        autopct='%.2f%%',
        pctdistance=0.8,
        labeldistance=1.5,
        shadow=True,
        startangle=0,
        radius=1.5,
        frame=False
       )

"""
explode:每部分偏移量
label:标签
colors:颜色
autopct:饼图上数据标签的显示方式
pctdistance:每个 并切片的中心和通过autopct生成的文本开始之间的比例
labeldistance:被画饼标记的直径，默认值1.1
shadow：阴影
"""
# Out:
# ([<matplotlib.patches.Wedge at 0x1b946250>,
# ...
#  [Text(0.8047516128127845, 2.101160356011702, 'a'),
#   Text(-1.8808172311166822, 1.2349196504771383, 'b'),
#   Text(-1.454454077359411, -1.716701295174144, 'c'),
#   Text(1.9877155935204656, -1.054270704930941, 'd')],
#  [Text(0.42920086016681847, 1.1206188565395745, '38.36%'),
#   Text(-1.0031025232622306, 0.6586238135878072, '4.79%'),
#   Text(-0.7757088412583527, -0.915574024092877, '41.33%'),
#   Text(1.0601149832109151, -0.562277709296502, '15.52%')])
