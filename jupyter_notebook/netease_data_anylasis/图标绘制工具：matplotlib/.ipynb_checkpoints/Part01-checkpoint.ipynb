# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.rand(10))
plt.show()

# %%
# 魔法函数，嵌入图表
# %matplotlib inline
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y)
#直接嵌入图表，不用plt.show()

# %%
#魔法函数，弹出可交互的matplotlib窗口
# %matplotlib notebook
s = pd.Series(np.random.randn(100))
s.plot(style='k--o', figsize=(10, 5))
#可交互的matplotlib窗口，不用plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#此处有点问题，后面解决

# %matplotlib qt5
df = pd.DataFrame(np.random.rand(50, 2), columns=['A', 'B'])
df.hist(figsize=(12, 5), color='g', alpha=0.8)
#可交互控制台
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-c48eace28d37> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt5')
#       2 df = pd.DataFrame(np.random.rand(50, 2), columns=['A', 'B'])
#       3 df.hist(figsize=(12, 5), color='g', alpha=0.8)
#       4 #可交互控制台
#
# d:\program files (x86)\py37\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-108> in matplotlib(self, line)
#
# d:\program files (x86)\py37\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# d:\program files (x86)\py37\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# d:\program files (x86)\py37\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3353                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3354
# -> 3355         pt.activate_matplotlib(backend)
#    3356         pt.configure_inline_support(self, backend)
#    3357
#
# d:\program files (x86)\py37\lib\site-packages\IPython\core\pylabtools.py in activate_matplotlib(backend)
#     312
#     313     import matplotlib.pyplot
# --> 314     matplotlib.pyplot.switch_backend(backend)
#     315
#     316     # This must be imported last in the matplotlib series, after
#
# d:\program files (x86)\py37\lib\site-packages\matplotlib\pyplot.py in switch_backend(newbackend)
#     205         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     206
# --> 207     backend_mod = importlib.import_module(backend_name)
#     208     Backend = type(
#     209         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# d:\program files (x86)\py37\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# d:\program files (x86)\py37\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# d:\program files (x86)\py37\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# d:\program files (x86)\py37\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# d:\program files (x86)\py37\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# d:\program files (x86)\py37\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# d:\program files (x86)\py37\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# d:\program files (x86)\py37\lib\site-packages\matplotlib\backends\backend_qt5agg.py in <module>
#       9 from .. import cbook
#      10 from .backend_agg import FigureCanvasAgg
# ---> 11 from .backend_qt5 import (
#      12     QtCore, QtGui, QtWidgets, _BackendQT5, FigureCanvasQT, FigureManagerQT,
#      13     NavigationToolbar2QT, backend_version)
#
# d:\program files (x86)\py37\lib\site-packages\matplotlib\backends\backend_qt5.py in <module>
#      13     _Backend, FigureCanvasBase, FigureManagerBase, NavigationToolbar2,
#      14     TimerBase, cursors, ToolContainerBase, StatusbarBase)
# ---> 15 import matplotlib.backends.qt_editor.figureoptions as figureoptions
#      16 from matplotlib.backends.qt_editor.formsubplottool import UiSubplotTool
#      17 from matplotlib.figure import Figure
#
# d:\program files (x86)\py37\lib\site-packages\matplotlib\backends\qt_editor\figureoptions.py in <module>
#      11 import matplotlib
#      12 from matplotlib import cm, colors as mcolors, markers, image as mimage
# ---> 13 import matplotlib.backends.qt_editor.formlayout as formlayout
#      14 from matplotlib.backends.qt_compat import QtGui
#      15
#
# d:\program files (x86)\py37\lib\site-packages\matplotlib\backends\qt_editor\formlayout.py in <module>
#      47
#      48 from matplotlib import colors as mcolors
# ---> 49 from matplotlib.backends.qt_compat import QtGui, QtWidgets, QtCore
#      50
#      51
#
# d:\program files (x86)\py37\lib\site-packages\matplotlib\backends\qt_compat.py in <module>
#     163         break
#     164     else:
# --> 165         raise ImportError("Failed to import any qt binding")
#     166 else:  # We should not get there.
#     167     raise AssertionError("Unexpected QT_API: {}".format(QT_API))
#
# ImportError: Failed to import any qt binding

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['A', 'B'])
print(df)
fig = df.plot(figsize=(6,4))
print(fig, type(fig))
# Out:
#           A         B
# 0  0.297913  0.552583
# 1  0.410655  0.789660
# 2  0.961065  0.761061
# 3  0.304318  0.597537
# 4  0.198217  0.067221
# 5  0.604446  0.232734
# 6  0.709368  0.258599
# 7  0.599568  0.293562
# 8  0.058206  0.035366
# 9  0.002148  0.518171
# AxesSubplot(0.125,0.125;0.775x0.755) <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)
plt.plot(x, c)
plt.plot(x, s)

plt.grid(True, linestyle='--', color='gray', linewidth='0.5', axis='x')
#显示网络
#linestyle:线型
#color:颜色
#linewidth:宽度
#axis:x,y,both,显示x/y/两者的格网


#刻度显示
# plt.tick_params(bottom='on', top='off', left='on', right='off')

#刻度的方向
import matplotlib
matplotlib.rcParams['xtick.direction'] = 'in'
matplotlib.rcParams['ytick.direction'] = 'out'

frame = plt.gca()
#关闭坐标轴
# plt.axis('off')
frame.axes.get_xaxis().set_visible(False)
# frame.axes.get_yaxis().set_visible(False)
#x/y轴不可见
